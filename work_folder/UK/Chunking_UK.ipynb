# %%
import xarray as xr 
import numpy as np
from tqdm import tqdm

# %%
# Find the HEALPix pixels that are closest to the ERA5 grid
res = 1
# longitudes and latitudes for the ERA5 grid
lon = np.arange(100,149+res,res)
lat = np.arange(-13, 13+res,res)

# %%
ds = xr.open_dataset("/scratch/nf33/hk25_LSP/UK/MC/cape_cin_3hourly.nc")

# %%
ds
# Out:
# <xarray.Dataset> Size: 31MB
# Dimensions:    (time: 2913, latitude: 27, longitude: 50)
# Coordinates:
#     crs        float64 8B nan
#   * time       (time) datetime64[ns] 23kB 2020-03-01 ... 2021-02-28
#   * latitude   (latitude) int64 216B -13 -12 -11 -10 -9 -8 ... 8 9 10 11 12 13
#   * longitude  (longitude) int64 400B 100 101 102 103 104 ... 146 147 148 149
# Data variables:
#     cape       (time, latitude, longitude) float32 16MB ...
#     cin        (time, latitude, longitude) float32 16MB ...

# %%
ds_coarse = ds.coarsen(longitude=2,latitude=2, boundary="trim").mean()

# %%
ds_coarse.to_netcdf('/scratch/nf33/hk25_LSP/UK/MC_chunk/cape_cin_2deg.nc')
# Out:
# /jobfs/140911377.gadi-pbs/ipykernel_278448/2285920006.py:1: SerializationWarning: saving variable latitude with floating point data as an integer dtype without any _FillValue to use for NaNs
#   ds_coarse.to_netcdf('/scratch/nf33/hk25_LSP/UK/MC_chunk/cape_cin_2deg.nc')
# /jobfs/140911377.gadi-pbs/ipykernel_278448/2285920006.py:1: SerializationWarning: saving variable longitude with floating point data as an integer dtype without any _FillValue to use for NaNs
#   ds_coarse.to_netcdf('/scratch/nf33/hk25_LSP/UK/MC_chunk/cape_cin_2deg.nc')

# %%
ds_coarse
# Out:
# <xarray.Dataset> Size: 8MB
# Dimensions:    (time: 2913, latitude: 13, longitude: 25)
# Coordinates:
#     crs        float64 8B nan
#   * time       (time) datetime64[ns] 23kB 2020-03-01 ... 2021-02-28
#   * latitude   (latitude) float64 104B -12.5 -10.5 -8.5 -6.5 ... 7.5 9.5 11.5
#   * longitude  (longitude) float64 200B 100.5 102.5 104.5 ... 144.5 146.5 148.5
# Data variables:
#     cape       (time, latitude, longitude) float32 4MB 2.043e+03 ... 684.0
#     cin        (time, latitude, longitude) float32 4MB 0.0 1.004 ... 21.75 25.36

# %%
# %%time
ds_w = xr.open_mfdataset("/scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_*.nc")
# Out:
# CPU times: user 4.09 s, sys: 1.32 s, total: 5.41 s
# Wall time: 12.3 s

# %%
ds_w_coarse = ds_w.coarsen(longitude=2,latitude=2, boundary="trim").mean()

# %%
ds_w_coarse["__xarray_dataarray_variable__"].to_dataset(name="wa").to_netcdf('/scratch/nf33/hk25_LSP/UK/MC_chunk/w500_2deg.nc')
# Out:
# /jobfs/140911377.gadi-pbs/ipykernel_278448/3735785445.py:1: SerializationWarning: saving variable cell with floating point data as an integer dtype without any _FillValue to use for NaNs
#   ds_w_coarse["__xarray_dataarray_variable__"].to_dataset(name="wa").to_netcdf('/scratch/nf33/hk25_LSP/UK/MC_chunk/w500_2deg.nc')
# /jobfs/140911377.gadi-pbs/ipykernel_278448/3735785445.py:1: SerializationWarning: saving variable latitude with floating point data as an integer dtype without any _FillValue to use for NaNs
#   ds_w_coarse["__xarray_dataarray_variable__"].to_dataset(name="wa").to_netcdf('/scratch/nf33/hk25_LSP/UK/MC_chunk/w500_2deg.nc')
# /jobfs/140911377.gadi-pbs/ipykernel_278448/3735785445.py:1: SerializationWarning: saving variable longitude with floating point data as an integer dtype without any _FillValue to use for NaNs
#   ds_w_coarse["__xarray_dataarray_variable__"].to_dataset(name="wa").to_netcdf('/scratch/nf33/hk25_LSP/UK/MC_chunk/w500_2deg.nc')

# %%
# %%time
ds_rh = xr.open_mfdataset("/scratch/nf33/hk25_LSP/UK/MC/hur_3hourly.nc")
# Out:
# CPU times: user 22.8 ms, sys: 59.9 ms, total: 82.7 ms
# Wall time: 1.61 s

# %%
ds_rh_coarse = ds_rh.coarsen(longitude=2,latitude=2, boundary="trim").mean()

# %%
ds_rh_coarse.to_netcdf('/scratch/nf33/hk25_LSP/UK/MC_chunk/rh500_2deg.nc')
# Out:
# /jobfs/140911377.gadi-pbs/ipykernel_278448/2417349955.py:1: SerializationWarning: saving variable cell with floating point data as an integer dtype without any _FillValue to use for NaNs
#   ds_rh_coarse.to_netcdf('/scratch/nf33/hk25_LSP/UK/MC_chunk/rh500_2deg.nc')
# /jobfs/140911377.gadi-pbs/ipykernel_278448/2417349955.py:1: SerializationWarning: saving variable latitude with floating point data as an integer dtype without any _FillValue to use for NaNs
#   ds_rh_coarse.to_netcdf('/scratch/nf33/hk25_LSP/UK/MC_chunk/rh500_2deg.nc')
# /jobfs/140911377.gadi-pbs/ipykernel_278448/2417349955.py:1: SerializationWarning: saving variable longitude with floating point data as an integer dtype without any _FillValue to use for NaNs
#   ds_rh_coarse.to_netcdf('/scratch/nf33/hk25_LSP/UK/MC_chunk/rh500_2deg.nc')
