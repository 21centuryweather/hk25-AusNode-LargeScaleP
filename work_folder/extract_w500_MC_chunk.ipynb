# %%
# Extract 3-hourly 500 hPa Omega from regridded vertical velocity (wa) data of UM zoom 6 model
import xarray as xr
from pathlib import Path
import easygems.healpix as egh
import healpy as hp
import numpy as np
from metpy.calc import vertical_velocity_pressure
from metpy.units import units
import pandas as pd

p = 500 # hPa; level of interest
data = "/g/data/qx55/uk_node/glm.n2560_RAL3p3/data.healpix.PT3H.z6.zarr" #PT1H is hourly data
ds = xr.open_zarr(data)

w = ds['wa'].sel(pressure=p)
t = ds['ta'].sel(pressure=p)

def get_nn_lon_lat_index(nside, lons, lats):
    """
    nside: integer, power of 2. The return of hp.get_nside()
    lons: uniques values of longitudes
    lats: uniques values of latitudes
    returns: array with the HEALPix cells that are closest to the lon/lat grid
    """
    lons2, lats2 = np.meshgrid(lons, lats)
    return xr.DataArray(
        hp.ang2pix(nside, lons2, lats2, nest = True, lonlat = True),
        coords=[("latitude", lats), ("longitude", lons)],
    )

# %%
from metpy.calc import vertical_velocity_pressure
from metpy.units import units

this_nside = hp.get_nside(w)
res = 1  # resolution
#MC lon: 100 - 149E, lat: 13S to 13N
lon = np.arange(100, 149 + res, res)
lat = np.arange(-13, 13 + res, res)

cells = get_nn_lon_lat_index(this_nside, lon, lat) 
w_regrid = w.isel(cell=cells)
t_regrid = t.isel(cell=cells)

omega = vertical_velocity_pressure(w_regrid * units('m/s'), 500 * units.hPa, t_regrid * units.degK)

# %%
# Create time selection (no need to modify)
full_range = pd.date_range(start="2020-03-01", end="2021-02-28", freq="3h")
date_str_list = full_range.strftime("%Y-%m-%dT%H:%M:%S").tolist()

#exclude_start = pd.Timestamp("2020-05-01 00:00:00")
#exclude_end = pd.Timestamp("2020-09-30 00:00:00")
#filtered_range = full_range[(full_range < exclude_start) | (full_range > exclude_end)]
#date_str_list = filtered_range.strftime("%Y-%m-%dT%H:%M:%S").tolist()

dir_out = '/scratch/nf33/hk25_LSP/UK/MC_chunk/'
Path(dir_out).mkdir(exist_ok=True)

# ✅ Start looping only over the gridded lat/lon (efficient)
grid_id = 1
for i in range(0, len(lat) - 2, 2):  # step 2
    for j in range(0, len(lon) - 2, 2):  # step 2
        lat_box = slice(lat[i], lat[i+2])
        lon_box = slice(lon[j], lon[j+2])

        try:
            w_box = w_regrid.sel(latitude=lat_box, longitude=lon_box)
            t_box = t_regrid.sel(latitude=lat_box, longitude=lon_box)

            omega = vertical_velocity_pressure(w_box * units('m/s'), p * units.hPa, t_box * units.degK)
            w500_box = omega.sel(time=date_str_list).mean(dim=("latitude", "longitude"))
            w500_box = w500_box.metpy.dequantify()

            fname = f'{dir_out}w500_3hr_{grid_id:03d}.nc'
            w500_box.to_netcdf(fname)
            print(f"Saved {fname}")

        except Exception as e:
            print(f"Skipped grid {grid_id:03d} due to error: {e}")

        grid_id += 1
# Out:
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_001.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_002.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_003.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_004.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_005.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_006.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_007.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_008.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_009.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_010.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_011.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_012.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_013.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_014.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_015.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_016.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_017.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_018.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_019.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_020.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_021.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_022.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_023.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_024.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_025.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_026.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_027.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_028.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_029.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_030.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_031.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_032.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_033.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_034.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_035.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_036.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_037.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_038.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_039.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_040.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_041.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_042.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_043.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_044.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_045.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_046.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_047.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_048.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_049.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_050.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_051.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_052.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_053.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_054.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_055.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_056.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_057.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_058.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_059.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_060.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_061.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_062.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_063.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_064.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_065.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_066.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_067.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_068.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_069.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_070.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_071.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_072.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_073.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_074.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_075.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_076.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_077.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_078.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_079.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_080.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_081.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_082.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_083.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_084.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_085.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_086.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_087.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_088.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_089.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_090.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_091.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_092.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_093.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_094.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_095.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_096.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_097.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_098.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_099.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_100.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_101.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_102.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_103.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_104.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_105.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_106.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_107.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_108.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_109.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_110.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_111.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_112.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_113.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_114.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_115.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_116.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_117.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_118.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_119.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_120.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_121.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_122.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_123.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_124.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_125.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_126.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_127.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_128.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_129.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_130.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_131.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_132.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_133.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_134.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_135.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_136.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_137.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_138.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_139.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_140.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_141.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_142.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_143.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_144.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_145.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_146.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_147.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_148.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_149.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_150.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_151.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_152.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_153.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_154.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_155.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_156.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_157.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_158.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_159.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_160.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_161.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_162.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_163.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_164.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_165.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_166.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_167.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_168.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_169.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_170.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_171.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_172.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_173.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_174.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_175.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_176.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_177.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_178.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_179.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_180.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_181.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_182.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_183.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_184.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_185.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_186.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_187.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_188.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_189.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_190.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_191.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_192.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_193.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_194.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_195.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_196.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_197.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_198.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_199.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_200.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_201.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_202.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_203.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_204.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_205.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_206.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_207.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_208.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_209.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_210.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_211.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_212.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_213.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_214.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_215.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_216.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_217.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_218.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_219.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_220.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_221.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_222.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_223.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_224.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_225.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_226.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_227.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_228.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_229.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_230.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_231.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_232.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_233.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_234.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_235.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_236.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_237.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_238.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_239.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_240.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_241.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_242.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_243.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_244.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_245.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_246.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_247.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_248.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_249.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_250.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_251.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_252.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_253.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_254.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_255.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_256.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_257.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_258.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_259.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_260.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_261.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_262.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_263.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_264.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_265.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_266.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_267.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_268.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_269.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_270.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_271.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_272.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_273.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_274.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_275.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_276.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_277.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_278.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_279.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_280.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_281.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_282.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_283.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_284.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_285.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_286.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_287.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_288.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_289.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_290.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_291.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_292.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_293.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_294.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_295.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_296.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_297.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_298.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_299.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_300.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_301.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_302.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_303.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_304.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_305.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_306.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_307.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_308.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_309.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_310.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_311.nc
# Saved /scratch/nf33/hk25_LSP/UK/MC_chunk/w500_3hr_312.nc
