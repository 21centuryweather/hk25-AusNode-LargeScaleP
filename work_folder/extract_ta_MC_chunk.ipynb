# %%
# Extract 3-hourly 500 hPa Temperature from regridded vertical velocity (hur) data of UM zoom 6 model
# Extract 6-ourly 500 hPa Temperature from regridded vertical velocity (hur) data of ICON zoom 6 model
import xarray as xr
from pathlib import Path
import easygems.healpix as egh
import healpy as hp
import numpy as np
from metpy.calc import vertical_velocity_pressure
from metpy.units import units
import pandas as pd

p = 500 # hPa; level of interest
data = "/g/data/qx55/uk_node/glm.n2560_RAL3p3/data.healpix.PT3H.z6.zarr" #PT1H is hourly data
data = "/g/data/qx55/germany_node/d3hp003.zarr/PT6H_point_z6_atm.zarr" #PT6H is 6-hourly data
ds = xr.open_zarr(data)

vname = 'ta'
#r = ds[vname].sel(pressure=slice(100,1000))
r = ds[vname].sel(pressure=slice(100*100,1000*100))

def get_nn_lon_lat_index(nside, lons, lats):
    """
    nside: integer, power of 2. The return of hp.get_nside()
    lons: uniques values of longitudes
    lats: uniques values of latitudes
    returns: array with the HEALPix cells that are closest to the lon/lat grid
    """
    lons2, lats2 = np.meshgrid(lons, lats)
    return xr.DataArray(
        hp.ang2pix(nside, lons2, lats2, nest = True, lonlat = True),
        coords=[("latitude", lats), ("longitude", lons)],
    )

r.attrs.pop("hiopy::time_method", None)
r.attrs.pop("hiopy::nnn",         None)
r.attrs.pop("hiopy::enable",      None)
# Out:
# True

# %%
this_nside = hp.get_nside(r.isel(pressure=1))
res = 1  # resolution
#MC lon: 100 - 149E, lat: 13S to 13N
lon = np.arange(100, 149 + res, res)
lat = np.arange(-13, 13 + res, res)

cells = get_nn_lon_lat_index(this_nside, lon, lat) 
r_regrid = r.isel(cell=cells)

# Create time selection (no need to modify)
#full_range = pd.date_range(start="2020-03-01", end="2021-02-28", freq="3h")
full_range = pd.date_range(start="2020-03-01", end="2021-02-28", freq="6h")
date_str_list = full_range.strftime("%Y-%m-%dT%H:%M:%S").tolist()

#exclude_start = pd.Timestamp("2020-05-01 00:00:00")
#exclude_end = pd.Timestamp("2020-09-30 00:00:00")
#filtered_range = full_range[(full_range < exclude_start) | (full_range > exclude_end)]
#date_str_list = filtered_range.strftime("%Y-%m-%dT%H:%M:%S").tolist()

dir_out = '/scratch/nf33/hk25_LSP/UK/MC_chunk/'
dir_out = '/scratch/nf33/hk25_LSP/Germany/MC_chunk/'
Path(dir_out).mkdir(exist_ok=True)

# ✅ Start looping only over the gridded lat/lon (efficient)
grid_id = 1
for i in range(0, len(lat) - 1, 2): 
    for j in range(0, len(lon) - 1, 2):  
        lat_box = slice(lat[i], lat[i+1])
        lon_box = slice(lon[j], lon[j+1])

        try:
            r_box = r_regrid.sel(latitude=lat_box, longitude=lon_box)

            #r500_box = r_box.sel(time=date_str_list).mean(dim=("latitude", "longitude"))
            r500_box = r_box.sel(time=date_str_list)#.mean(dim=("latitude", "longitude"))
            r500_box = r500_box.to_dataset(name=vname)

            fname = f'{dir_out}{vname}_3hr_{grid_id:03d}.nc'
            fname = f'{dir_out}{vname}_6hr_{grid_id:03d}.nc'
            r500_box.to_netcdf(fname)
            print(f"Saved {fname}")

        except Exception as e:
            print(f"Skipped grid {grid_id:03d} due to error: {e}")

        grid_id += 1
# Out:
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_001.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_002.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_003.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_004.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_005.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_006.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_007.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_008.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_009.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_010.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_011.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_012.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_013.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_014.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_015.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_016.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_017.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_018.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_019.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_020.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_021.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_022.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_023.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_024.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_025.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_026.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_027.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_028.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_029.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_030.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_031.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_032.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_033.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_034.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_035.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_036.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_037.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_038.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_039.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_040.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_041.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_042.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_043.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_044.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_045.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_046.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_047.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_048.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_049.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_050.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_051.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_052.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_053.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_054.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_055.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_056.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_057.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_058.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_059.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_060.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_061.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_062.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_063.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_064.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_065.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_066.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_067.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_068.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_069.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_070.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_071.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_072.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_073.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_074.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_075.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_076.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_077.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_078.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_079.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_080.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_081.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_082.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_083.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_084.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_085.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_086.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_087.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_088.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_089.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_090.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_091.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_092.nc
# Saved /scratch/nf33/hk25_LSP/Germany/MC_chunk/ta_6hr_093.nc
