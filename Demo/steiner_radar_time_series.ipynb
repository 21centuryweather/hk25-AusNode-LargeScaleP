# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
from scipy import ndimage
from skimage.measure import label
from tqdm import tqdm
import re
from multiprocess import Pool
import os

# %% [markdown]
# Following Louf et al. (2019), we only need take wet seasons (October to April)
#
# The simulation is from 2020-03-01 to 2021-02-28
#
# So data between 2020-04-30 and 2020-09-30 are not considered for now

# %% [markdown]
# I'll test with Steiner classification first and then just use the precipitation threshold (with object size more than 5 grid points in radar to remove some ground clutter)

# %%
import pandas as pd

# Create full date range from 2020-03-01 to 2021-02-28
full_range = pd.date_range(start="2020-03-01", end="2021-02-28", freq="D")

# Define exclusion period
exclude_start = pd.Timestamp("2020-05-01")
exclude_end = pd.Timestamp("2020-09-30")

# Filter out the excluded range
filtered_range = full_range[(full_range < exclude_start) | (full_range > exclude_end)]

# Convert to list of strings in yyyymmdd format
date_str_list = filtered_range.strftime("%Y%m%d").tolist()

# %%
def calc_clouds(yyyymmdd):
    ## initialisation
    steiner_file = f"/g/data/rq0/level_2/63/STEINER/63_{yyyymmdd}_steiner.nc"
    if os.path.exists(steiner_file):
        ds_radar = xr.open_dataset(steiner_file)
        radar_area = len(np.argwhere(~np.isnan(ds_radar["steiner"].isel(time=0).values)))
        ds_prcp = xr.open_dataset(f"/g/data/rq0/admin/level_2_decomissioned_fields/63/RAINRATE/63_{yyyymmdd}_rainrate.nc")
        ## array to store object number
        num_obj_arr = np.zeros(len(ds_radar.time))
        
        ## array for total area
        tot_area_arr = np.zeros(len(ds_radar.time))
        ## array to store mean cell size
        mean_obj_area_arr = np.zeros(len(ds_radar.time))
        ## array to store convective area fraction
        area_frac_arr = np.zeros(len(ds_radar.time))
        ## mean precipitation over convective area
        cvt_mean_prcp_arr = np.zeros(len(ds_radar.time))
        ## mean precipitation over the entire radar scan
        tot_mean_prcp_arr = np.zeros(len(ds_radar.time))
        ## total convective precipitation
        cvt_tot_prcp_arr = np.zeros(len(ds_radar.time))
        
        for its in range(0,len(ds_radar.time)):
            data = ds_radar["steiner"].isel(time=its)
            prcp = ds_prcp["rainrate"].isel(time=its)
            cvt_prcp = np.sum(prcp.values[data.values==2])    
            cv_obj = data.copy().fillna(0)
            cv_obj.values[cv_obj.values < 2] = 0
            ## use scikit learn to label
            label_arr = label(cv_obj)
            ## find unique objects
            unique_label = np.unique(label_arr)
            ## get the number of objects 
            num_obj_arr[its] = len(unique_label) - 1   ## the background is 0
            ## individual object area
            ind_obj_area = np.zeros(len(unique_label) - 1)
            
            for i in unique_label:
                if i == 0:
                    continue
                else:
                    ind_obj_area[i-1]= np.sum(label_arr == i) ## the data is 1 km by 1 km so this is exactly the area
                    ## this may be needed for precip thresholds
                    # if obj_area <=5:
                    #     label_new[label_new==i] = 0
            
            tot_area_arr[its] = np.sum(ind_obj_area)
            mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
            area_frac_arr[its] = tot_area_arr[its]/radar_area
        
            cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
            tot_mean_prcp_arr[its] = cvt_prcp/radar_area
            cvt_tot_prcp_arr[its] = cvt_prcp
    
        ## save to netcdf
        out = xr.Dataset(
            {
                "num_obj": (("time"), num_obj_arr),
                "tot_area":  (("time"), tot_area_arr),
                "mean_obj_area":  (("time"), mean_obj_area_arr),
                "area_frac":  (("time"), area_frac_arr),
                "cvt_mean_prcp":  (("time"), cvt_mean_prcp_arr),
                "tot_mean_prcp":  (("time"), tot_mean_prcp_arr),
                "cvt_tot_prcp":  (("time"), cvt_tot_prcp_arr),
                
            },
            coords={
                "time":  ds_radar.time.values,
            },
        )
        out.to_netcdf(f"/scratch/k10/dl6968/prep_hk25/steiner_ts/number_size_{yyyymmdd}.nc")
        out.close()
        ds_radar.close()
        ds_prcp.close()

# %%
## parallelise this
max_pool=24

with Pool(max_pool) as p:
    pool_outputs = list(
        tqdm(
            p.imap(calc_clouds,
                   date_str_list),
            total=len(date_str_list),
            position=0, leave=True
        )
    )
p.join()
# Out:
#   0%|          | 0/212 [00:00<?, ?it/s]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:50: RuntimeWarning: invalid value encountered in scalar divide
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: invalid value encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:50: RuntimeWarning: invalid value encountered in scalar divide
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: invalid value encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:50: RuntimeWarning: divide by zero encountered in scalar divide
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: divide by zero encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#   0%|          | 1/212 [01:05<3:51:31, 65.84s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  11%|█▏        | 24/212 [01:08<05:11,  1.66s/it] /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:50: RuntimeWarning: divide by zero encountered in scalar divide
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: divide by zero encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  12%|█▏        | 25/212 [02:00<18:49,  6.04s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  12%|█▏        | 26/212 [02:03<17:44,  5.72s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  13%|█▎        | 27/212 [02:04<15:36,  5.06s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  13%|█▎        | 28/212 [02:06<13:57,  4.55s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  17%|█▋        | 35/212 [02:07<05:04,  1.72s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  18%|█▊        | 39/212 [02:12<04:15,  1.47s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  19%|█▉        | 41/212 [02:22<06:34,  2.31s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  23%|██▎       | 49/212 [02:59<09:52,  3.63s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  24%|██▎       | 50/212 [03:07<10:41,  3.96s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  25%|██▌       | 54/212 [03:11<07:55,  3.01s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  29%|██▉       | 62/212 [03:35<07:32,  3.01s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  31%|███       | 65/212 [03:43<07:08,  2.92s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:50: RuntimeWarning: invalid value encountered in scalar divide
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: invalid value encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  33%|███▎      | 69/212 [03:50<06:04,  2.55s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:50: RuntimeWarning: invalid value encountered in scalar divide
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: invalid value encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
#  34%|███▍      | 72/212 [03:52<05:03,  2.17s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:50: RuntimeWarning: divide by zero encountered in scalar divide
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: divide by zero encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:50: RuntimeWarning: divide by zero encountered in scalar divide
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: divide by zero encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
#  34%|███▍      | 73/212 [04:29<12:56,  5.58s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  35%|███▍      | 74/212 [04:35<13:10,  5.73s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  40%|████      | 85/212 [04:48<04:55,  2.33s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  41%|████      | 86/212 [05:02<06:56,  3.31s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  42%|████▏     | 88/212 [05:10<06:54,  3.34s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:50: RuntimeWarning: invalid value encountered in scalar divide
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: invalid value encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
#  42%|████▏     | 89/212 [05:11<06:03,  2.96s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:50: RuntimeWarning: divide by zero encountered in scalar divide
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: divide by zero encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
#  43%|████▎     | 91/212 [05:16<05:39,  2.81s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  45%|████▍     | 95/212 [05:20<03:43,  1.91s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  45%|████▌     | 96/212 [05:21<03:35,  1.86s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  46%|████▌     | 98/212 [06:03<13:31,  7.12s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  48%|████▊     | 102/212 [06:09<06:45,  3.69s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  49%|████▉     | 104/212 [06:16<06:36,  3.67s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  52%|█████▏    | 110/212 [06:30<05:22,  3.16s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:50: RuntimeWarning: invalid value encountered in scalar divide
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: invalid value encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:50: RuntimeWarning: divide by zero encountered in scalar divide
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: divide by zero encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
#  52%|█████▏    | 111/212 [06:44<08:22,  4.98s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  55%|█████▌    | 117/212 [06:49<03:58,  2.51s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  57%|█████▋    | 120/212 [06:56<03:39,  2.39s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  57%|█████▋    | 121/212 [07:37<12:38,  8.33s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:50: RuntimeWarning: invalid value encountered in scalar divide
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: invalid value encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:50: RuntimeWarning: divide by zero encountered in scalar divide
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: divide by zero encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
# ...
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: divide by zero encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
#  60%|██████    | 128/212 [07:45<04:47,  3.42s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:50: RuntimeWarning: invalid value encountered in scalar divide
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: invalid value encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
#  63%|██████▎   | 133/212 [07:49<02:41,  2.05s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:50: RuntimeWarning: divide by zero encountered in scalar divide
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: divide by zero encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  64%|██████▎   | 135/212 [08:07<04:46,  3.73s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  64%|██████▍   | 136/212 [08:19<06:43,  5.31s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  67%|██████▋   | 141/212 [08:27<03:27,  2.92s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  67%|██████▋   | 142/212 [08:29<03:21,  2.88s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  67%|██████▋   | 143/212 [08:33<03:34,  3.11s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  68%|██████▊   | 145/212 [09:00<07:39,  6.86s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  70%|██████▉   | 148/212 [09:23<08:04,  7.56s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  75%|███████▍  | 158/212 [09:24<01:38,  1.83s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  75%|███████▌  | 159/212 [09:42<03:00,  3.41s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:50: RuntimeWarning: invalid value encountered in scalar divide
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: invalid value encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:50: RuntimeWarning: divide by zero encountered in scalar divide
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: divide by zero encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:50: RuntimeWarning: invalid value encountered in scalar divide
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: invalid value encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:50: RuntimeWarning: divide by zero encountered in scalar divide
#   area_frac_arr[its] = tot_area_arr[its]/radar_area
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:53: RuntimeWarning: divide by zero encountered in divide
#   tot_mean_prcp_arr[its] = cvt_prcp/radar_area
#  79%|███████▉  | 167/212 [10:11<02:15,  3.00s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  80%|███████▉  | 169/212 [10:25<02:38,  3.69s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  81%|████████  | 171/212 [10:40<03:08,  4.60s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  86%|████████▌ | 182/212 [11:00<01:02,  2.07s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  86%|████████▋ | 183/212 [11:15<02:22,  4.90s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  87%|████████▋ | 185/212 [11:28<02:23,  5.32s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
#  88%|████████▊ | 187/212 [11:36<01:53,  4.52s/it]/jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   mean_obj_area_arr[its] = tot_area_arr[its]/num_obj_arr[its]
# /jobfs/140243372.gadi-pbs/ipykernel_239488/1369187819.py:52: RuntimeWarning: invalid value encountered in scalar divide
#   cvt_mean_prcp_arr[its] = cvt_prcp/tot_area_arr[its]
# 100%|██████████| 212/212 [12:57<00:00,  3.67s/it]
